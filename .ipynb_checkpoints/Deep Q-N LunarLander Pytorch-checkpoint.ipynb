# %%
import torch as T
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import pandas as pd
import gym

# %%
information = {"Deep Q-Network":{"Lunar Landing":{}}}

# %% [markdown]
# # Deep Q-Neural Network for Lunar Lander

# %% [markdown]
# ### Build Deep Q-Neural Network

# %%
class DQN(nn.Module):
    def __init__(self, lr, input_dims, fc1_dims, fc2_dims, n_actions):
        super(DQN, self).__init__()
        self.input_dims = input_dims
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.n_actions = n_actions
        self.fc1 = nn.Linear(*self.input_dims, self.fc1_dims)
        self.fc2 = nn.Linear(self.fc1_dims, self.fc2_dims)
        self.fc3 = nn.Linear(self.fc2_dims, self.n_actions)
        self.optimizer = optim.Adam(self.parameters(), lr=lr)
        self.loss = nn.MSELoss()
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.to(self.device)
        
    def forward(self, state):
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        actions = self.fc3(x)
        return actions

# %% [markdown]
# ### Build Double Deep Q-Neural Network

# %%
class DDQN(nn.Module):
    def __init__(self, lr, input_dims, fc1_dims, fc2_dims, n_actions):
        super(DQN, self).__init__()
        self.input_dims = input_dims
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.n_actions = n_actions
        self.fc1 = nn.Linear(*self.input_dims, self.fc1_dims)
        self.fc2 = nn.Linear(self.fc1_dims, self.fc2_dims)
        self.fc3 = nn.Linear(self.fc2_dims, self.n_actions)
        self.optimizer = optim.Adam(self.parameters(), lr=lr)
        self.loss = nn.MSELoss()
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.to(self.device)
        
    def forward(self, state):
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        actions = self.fc3(x)
        return actions

# %% [markdown]
# ### Build Learning Agent

# %%
class AgentDQN():
    def __init__(self, gamma, epsilon, lr, input_dims, batch_size, n_actions,
                max_mem_size = 100000, eps_end = 0.01, eps_dec = 5e-4):
        self.gamma = gamma
        self.epsilon = epsilon
        self.eps_min = eps_end
        self.eps_dec = eps_dec
        self.lr = lr
        self.action_space = [i for i in range(n_actions)]
        self.mem_size = max_mem_size
        self.batch_size = batch_size
        self.mem_cntr = 0
        
        self.Q_eval = DQN(self.lr, n_actions=n_actions, input_dims=input_dims,
                          fc1_dims=256, fc2_dims=256)
        
        self.state_memory = np.zeros((self.mem_size, *input_dims), dtype=np.float32)
        self.new_state_memory = np.zeros((self.mem_size, *input_dims), dtype=np.float32)
        self.action_memory = np.zeros(self.mem_size, dtype=np.int32)
        self.reward_memory = np.zeros(self.mem_size, dtype=np.float32)
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.bool)
        
        self.loss_history = []
        
    def store_transition(self, state, action, reward, state_, done):
        index = self.mem_cntr % self.mem_size
        self.state_memory[index] = state
        self.new_state_memory[index] = state_
        self.reward_memory[index] = reward
        self.action_memory[index] = action
        self.terminal_memory[index] = done
        
        self.mem_cntr += 1
        
    def choose_action(self, observation):
        if np.random.random() > self.epsilon:
            state = T.tensor([observation]).to(self.Q_eval.device)
            actions = self.Q_eval.forward(state)
            action = T.argmax(actions).item()
        else:
            action = np.random.choice(self.action_space)
            
        return action
        
    def learn(self):
        if self.mem_cntr < self.batch_size:
            return
        self.Q_eval.optimizer.zero_grad()
        
        max_mem = min(self.mem_cntr, self.mem_size)
        batch = np.random.choice(max_mem, self.batch_size, replace=False)
        
        batch_index = np.arange(self.batch_size, dtype=np.int32)
        
        state_batch = T.tensor(self.state_memory[batch]).to(self.Q_eval.device)
        new_state_batch = T.tensor(self.new_state_memory[batch]).to(self.Q_eval.device)
        reward_batch = T.tensor(self.reward_memory[batch]).to(self.Q_eval.device)
        terminal_batch = T.tensor(self.terminal_memory[batch]).to(self.Q_eval.device)
        
        action_batch = self.action_memory[batch]
        
        q_eval = self.Q_eval.forward(state_batch)[batch_index, action_batch]
        q_next = self.Q_eval.forward(new_state_batch)
        q_next[terminal_batch] = 0.0
        
        q_target = reward_batch + self.gamma * T.max(q_next, dim=1)[0]
        
        loss = self.Q_eval.loss(q_target, q_eval).to(self.Q_eval.device)
        loss.backward()
        self.Q_eval.optimizer.step()
        
        self.epsilon = self.epsilon - self.eps_dec if self.epsilon > self.eps_min else self.eps_min
        
        self.loss_history.append(loss.item())
    
    def get_loss_history(self):
        history = self.loss_history
        return history

# %%
class AgentDQN():
    def __init__(self, gamma, epsilon, lr, input_dims, batch_size, n_actions,
                max_mem_size = 100000, eps_end = 0.01, eps_dec = 5e-4):
        self.gamma = gamma
        self.epsilon = epsilon
        self.eps_min = eps_end
        self.eps_dec = eps_dec
        self.lr = lr
        self.action_space = [i for i in range(n_actions)]
        self.mem_size = max_mem_size
        self.batch_size = batch_size
        self.mem_cntr = 0
        
        self.Q_eval = DQN(self.lr, n_actions=n_actions, input_dims=input_dims,
                          fc1_dims=256, fc2_dims=256)
        
        self.state_memory = np.zeros((self.mem_size, *input_dims), dtype=np.float32)
        self.new_state_memory = np.zeros((self.mem_size, *input_dims), dtype=np.float32)
        self.action_memory = np.zeros(self.mem_size, dtype=np.int32)
        self.reward_memory = np.zeros(self.mem_size, dtype=np.float32)
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.bool)
        
        self.loss_history = []
        
    def store_transition(self, state, action, reward, state_, done):
        index = self.mem_cntr % self.mem_size
        self.state_memory[index] = state
        self.new_state_memory[index] = state_
        self.reward_memory[index] = reward
        self.action_memory[index] = action
        self.terminal_memory[index] = done
        
        self.mem_cntr += 1
        
    def choose_action(self, observation):
        if np.random.random() > self.epsilon:
            state = T.tensor([observation]).to(self.Q_eval.device)
            actions = self.Q_eval.forward(state)
            action = T.argmax(actions).item()
        else:
            action = np.random.choice(self.action_space)
            
        return action
        
    def learn(self):
        if self.mem_cntr < self.batch_size:
            return
        self.Q_eval.optimizer.zero_grad()
        
        max_mem = min(self.mem_cntr, self.mem_size)
        batch = np.random.choice(max_mem, self.batch_size, replace=False)
        
        batch_index = np.arange(self.batch_size, dtype=np.int32)
        
        state_batch = T.tensor(self.state_memory[batch]).to(self.Q_eval.device)
        new_state_batch = T.tensor(self.new_state_memory[batch]).to(self.Q_eval.device)
        reward_batch = T.tensor(self.reward_memory[batch]).to(self.Q_eval.device)
        terminal_batch = T.tensor(self.terminal_memory[batch]).to(self.Q_eval.device)
        
        action_batch = self.action_memory[batch]
        
        q_eval = self.Q_eval.forward(state_batch)[batch_index, action_batch]
        q_next = self.Q_eval.forward(new_state_batch)
        q_next[terminal_batch] = 0.0
        
        q_target = reward_batch + self.gamma * T.max(q_next, dim=1)[0]
        
        loss = self.Q_eval.loss(q_target, q_eval).to(self.Q_eval.device)
        loss.backward()
        self.Q_eval.optimizer.step()
        
        self.epsilon = self.epsilon - self.eps_dec if self.epsilon > self.eps_min else self.eps_min
        
        self.loss_history.append(loss.item())
    
    def get_loss_history(self):
        history = self.loss_history
        return history

# %% [markdown]
# # Training the Agent to play LunarLander

# %%
env = gym.make('LunarLander-v2')
agent = AgentDQN(gamma=0.99, epsilon=1.0, batch_size=64, n_actions=4, eps_end=0.01,
                  input_dims=[8], lr=0.001)
scores, eps_history = [], []
n_games = 300
    
for i in range(n_games):
    score = 0
    done = False
    observation = env.reset()
    while not done:
        env.render()
        action = agent.choose_action(observation)
        observation_, reward, done, info = env.step(action)
        score += reward
        agent.store_transition(observation, action, reward, 
                                    observation_, done)
        agent.learn()
        observation = observation_
    scores.append(score)
    eps_history.append(agent.epsilon)

    avg_score = np.mean(scores[-100:])

    print('episode ', i, 'score %.2f' % score,
                'average score %.2f' % avg_score,
                'epsilon %.2f' % agent.epsilon)
env.close()

information["Deep Q-Network"]["Lunar Landing"]["Epsilon"] = eps_history
information["Deep Q-Network"]["Lunar Landing"]["Reward"] = scores
# Out:
# episode  0 score -149.04 average score -149.04 epsilon 0.99
# episode  1 score -134.87 average score -141.95 epsilon 0.96
# episode  2 score -72.94 average score -118.95 epsilon 0.92
# episode  3 score -118.65 average score -118.87 epsilon 0.86
# episode  4 score -213.05 average score -137.71 epsilon 0.80
# episode  5 score -55.50 average score -124.01 epsilon 0.75
# episode  6 score -89.06 average score -119.02 epsilon 0.72
# episode  7 score -25.10 average score -107.28 epsilon 0.65
# episode  8 score -186.01 average score -116.02 epsilon 0.52
# episode  9 score -124.78 average score -116.90 epsilon 0.46
# episode  10 score -81.23 average score -113.66 epsilon 0.34
# episode  11 score -430.29 average score -140.04 epsilon 0.21
# episode  12 score -120.47 average score -138.54 epsilon 0.09
# episode  13 score -248.60 average score -146.40 epsilon 0.01
# episode  14 score -126.89 average score -145.10 epsilon 0.01
# episode  15 score 275.73 average score -118.80 epsilon 0.01
# episode  16 score 120.60 average score -104.71 epsilon 0.01
# episode  17 score -102.73 average score -104.60 epsilon 0.01
# episode  18 score -14.05 average score -99.84 epsilon 0.01
# episode  19 score -224.36 average score -106.06 epsilon 0.01
# episode  20 score -240.49 average score -112.46 epsilon 0.01
# episode  21 score -76.18 average score -110.82 epsilon 0.01
# episode  22 score -70.41 average score -109.06 epsilon 0.01
# episode  23 score -280.12 average score -116.19 epsilon 0.01
# episode  24 score -333.76 average score -124.89 epsilon 0.01
# episode  25 score -168.45 average score -126.56 epsilon 0.01
# episode  26 score -118.41 average score -126.26 epsilon 0.01
# episode  27 score -240.38 average score -130.34 epsilon 0.01
# episode  28 score -286.01 average score -135.71 epsilon 0.01
# episode  29 score -111.81 average score -134.91 epsilon 0.01
# episode  30 score -82.70 average score -133.23 epsilon 0.01
# episode  31 score -313.37 average score -138.86 epsilon 0.01
# episode  32 score -536.06 average score -150.89 epsilon 0.01
# episode  33 score -399.03 average score -158.19 epsilon 0.01
# episode  34 score -292.60 average score -162.03 epsilon 0.01
# episode  35 score -364.85 average score -167.66 epsilon 0.01
# episode  36 score -477.58 average score -176.04 epsilon 0.01
# episode  37 score -517.54 average score -185.03 epsilon 0.01
# episode  38 score -436.62 average score -191.48 epsilon 0.01
# episode  39 score -774.48 average score -206.05 epsilon 0.01
# episode  40 score -602.95 average score -215.73 epsilon 0.01
# episode  41 score -739.72 average score -228.21 epsilon 0.01
# episode  42 score -449.26 average score -233.35 epsilon 0.01
# episode  43 score -443.37 average score -238.12 epsilon 0.01
# episode  44 score -468.48 average score -243.24 epsilon 0.01
# episode  45 score -470.14 average score -248.17 epsilon 0.01
# episode  46 score -597.46 average score -255.61 epsilon 0.01
# episode  47 score -603.30 average score -262.85 epsilon 0.01
# episode  48 score -262.80 average score -262.85 epsilon 0.01
# episode  49 score -347.12 average score -264.53 epsilon 0.01
# episode  50 score -46.97 average score -260.27 epsilon 0.01
# episode  51 score -331.68 average score -261.64 epsilon 0.01
# episode  52 score 205.25 average score -252.83 epsilon 0.01
# episode  53 score 251.48 average score -243.49 epsilon 0.01
# episode  54 score -35.06 average score -239.70 epsilon 0.01
# episode  55 score -88.56 average score -237.00 epsilon 0.01
# episode  56 score -85.23 average score -234.34 epsilon 0.01
# episode  57 score -93.85 average score -231.92 epsilon 0.01
# episode  58 score -89.39 average score -229.50 epsilon 0.01
# episode  59 score 154.48 average score -223.10 epsilon 0.01
# episode  60 score -135.33 average score -221.66 epsilon 0.01
# episode  61 score -128.65 average score -220.16 epsilon 0.01
# episode  62 score -357.65 average score -222.35 epsilon 0.01
# episode  63 score -59.01 average score -219.79 epsilon 0.01
# episode  64 score -396.45 average score -222.51 epsilon 0.01
# episode  65 score -49.28 average score -219.89 epsilon 0.01
# episode  66 score -267.01 average score -220.59 epsilon 0.01
# episode  67 score -27.06 average score -217.75 epsilon 0.01
# episode  68 score -3.77 average score -214.64 epsilon 0.01
# episode  69 score -100.97 average score -213.02 epsilon 0.01
# episode  70 score -55.94 average score -210.81 epsilon 0.01
# episode  71 score -216.03 average score -210.88 epsilon 0.01
# episode  72 score -106.90 average score -209.46 epsilon 0.01
# episode  73 score 17.84 average score -206.38 epsilon 0.01
# episode  74 score -74.17 average score -204.62 epsilon 0.01
# episode  75 score -61.24 average score -202.73 epsilon 0.01
# episode  76 score -126.53 average score -201.75 epsilon 0.01
# episode  77 score -115.41 average score -200.64 epsilon 0.01
# episode  78 score -133.93 average score -199.79 epsilon 0.01
# episode  79 score -240.56 average score -200.30 epsilon 0.01
# episode  80 score 121.60 average score -196.33 epsilon 0.01
# episode  81 score -222.22 average score -196.65 epsilon 0.01
# episode  82 score -279.14 average score -197.64 epsilon 0.01
# episode  83 score -351.36 average score -199.47 epsilon 0.01
# episode  84 score -54.84 average score -197.77 epsilon 0.01
# episode  85 score -18.23 average score -195.68 epsilon 0.01
# episode  86 score -86.09 average score -194.42 epsilon 0.01
# episode  87 score -23.99 average score -192.48 epsilon 0.01
# episode  88 score -24.79 average score -190.60 epsilon 0.01
# episode  89 score -107.29 average score -189.67 epsilon 0.01
# episode  90 score -146.81 average score -189.20 epsilon 0.01
# episode  91 score -54.18 average score -187.73 epsilon 0.01
# episode  92 score -13.30 average score -185.86 epsilon 0.01
# episode  93 score -47.54 average score -184.39 epsilon 0.01
# episode  94 score -55.32 average score -183.03 epsilon 0.01
# episode  95 score -54.93 average score -181.69 epsilon 0.01
# episode  96 score -34.93 average score -180.18 epsilon 0.01
# episode  97 score -65.86 average score -179.02 epsilon 0.01
# episode  98 score -42.74 average score -177.64 epsilon 0.01
# episode  99 score 19.31 average score -175.67 epsilon 0.01
# episode  100 score -126.38 average score -175.44 epsilon 0.01
# episode  101 score -5.32 average score -174.15 epsilon 0.01
# episode  102 score -35.57 average score -173.77 epsilon 0.01
# episode  103 score -59.52 average score -173.18 epsilon 0.01
# episode  104 score -47.31 average score -171.52 epsilon 0.01
# episode  105 score -15.84 average score -171.13 epsilon 0.01
# episode  106 score -16.50 average score -170.40 epsilon 0.01
# episode  107 score -52.54 average score -170.68 epsilon 0.01
# episode  108 score 163.54 average score -167.18 epsilon 0.01
# episode  109 score -14.47 average score -166.08 epsilon 0.01
# episode  110 score -9.08 average score -165.36 epsilon 0.01
# episode  111 score 134.77 average score -159.71 epsilon 0.01
# episode  112 score -47.57 average score -158.98 epsilon 0.01
# episode  113 score -28.93 average score -156.78 epsilon 0.01
# episode  114 score 143.97 average score -154.07 epsilon 0.01
# episode  115 score -21.42 average score -157.04 epsilon 0.01
# episode  116 score 9.69 average score -158.15 epsilon 0.01
# episode  117 score 21.24 average score -156.91 epsilon 0.01
# episode  118 score -12.55 average score -156.90 epsilon 0.01
# episode  119 score 175.56 average score -152.90 epsilon 0.01
# episode  120 score -45.50 average score -150.95 epsilon 0.01
# episode  121 score -44.52 average score -150.63 epsilon 0.01
# episode  122 score -30.02 average score -150.23 epsilon 0.01
# episode  123 score 29.39 average score -147.13 epsilon 0.01
# episode  124 score -22.04 average score -144.02 epsilon 0.01
# episode  125 score 147.52 average score -140.86 epsilon 0.01
# episode  126 score 188.02 average score -137.79 epsilon 0.01
# episode  127 score -11.00 average score -135.50 epsilon 0.01
# episode  128 score -12.74 average score -132.77 epsilon 0.01
# episode  129 score 199.47 average score -129.65 epsilon 0.01
# episode  130 score 195.87 average score -126.87 epsilon 0.01
# episode  131 score 204.27 average score -121.69 epsilon 0.01
# episode  132 score -41.96 average score -116.75 epsilon 0.01
# episode  133 score 177.45 average score -110.99 epsilon 0.01
# episode  134 score 242.91 average score -105.63 epsilon 0.01
# episode  135 score 190.78 average score -100.07 epsilon 0.01
# episode  136 score -23.59 average score -95.53 epsilon 0.01
# episode  137 score 110.08 average score -89.26 epsilon 0.01
# episode  138 score 179.92 average score -83.09 epsilon 0.01
# episode  139 score 12.76 average score -75.22 epsilon 0.01
# episode  140 score -81.07 average score -70.00 epsilon 0.01
# episode  141 score 99.43 average score -61.61 epsilon 0.01
# episode  142 score 229.61 average score -54.82 epsilon 0.01
# episode  143 score 231.63 average score -48.07 epsilon 0.01
# episode  144 score 234.92 average score -41.04 epsilon 0.01
# episode  145 score 187.48 average score -34.46 epsilon 0.01
# episode  146 score 36.09 average score -28.13 epsilon 0.01
# episode  147 score 224.63 average score -19.85 epsilon 0.01
# episode  148 score -67.07 average score -17.89 epsilon 0.01
# episode  149 score -64.65 average score -15.06 epsilon 0.01
# episode  150 score 209.27 average score -12.50 epsilon 0.01
# episode  151 score 193.39 average score -7.25 epsilon 0.01
# episode  152 score 1.68 average score -9.29 epsilon 0.01
# episode  153 score 106.80 average score -10.73 epsilon 0.01
# episode  154 score 91.80 average score -9.46 epsilon 0.01
# episode  155 score -5.34 average score -8.63 epsilon 0.01
# episode  156 score -62.98 average score -8.41 epsilon 0.01
# episode  157 score -67.72 average score -8.15 epsilon 0.01
# episode  158 score -96.93 average score -8.22 epsilon 0.01
# episode  159 score 42.67 average score -9.34 epsilon 0.01
# episode  160 score -6.83 average score -8.06 epsilon 0.01
# episode  161 score 259.41 average score -4.18 epsilon 0.01
# episode  162 score -49.59 average score -1.10 epsilon 0.01
# episode  163 score 254.88 average score 2.04 epsilon 0.01
# episode  164 score 211.98 average score 8.13 epsilon 0.01
# episode  165 score 227.94 average score 10.90 epsilon 0.01
# episode  166 score 195.34 average score 15.52 epsilon 0.01
# episode  167 score 127.22 average score 17.07 epsilon 0.01
# episode  168 score 21.73 average score 17.32 epsilon 0.01
# episode  169 score 242.30 average score 20.75 epsilon 0.01
# episode  170 score 206.75 average score 23.38 epsilon 0.01
# episode  171 score 184.21 average score 27.38 epsilon 0.01
# episode  172 score -109.66 average score 27.35 epsilon 0.01
# episode  173 score 219.09 average score 29.37 epsilon 0.01
# episode  174 score -62.07 average score 29.49 epsilon 0.01
# episode  175 score 306.52 average score 33.17 epsilon 0.01
# episode  176 score 210.19 average score 36.53 epsilon 0.01
# episode  177 score 195.50 average score 39.64 epsilon 0.01
# episode  178 score 259.15 average score 43.57 epsilon 0.01
# episode  179 score 202.94 average score 48.01 epsilon 0.01
# episode  180 score 219.79 average score 48.99 epsilon 0.01
# episode  181 score 215.09 average score 53.36 epsilon 0.01
# episode  182 score 244.85 average score 58.60 epsilon 0.01
# episode  183 score 191.93 average score 64.04 epsilon 0.01
# episode  184 score 209.48 average score 66.68 epsilon 0.01
# episode  185 score 272.89 average score 69.59 epsilon 0.01
# episode  186 score 198.58 average score 72.44 epsilon 0.01
# episode  187 score 249.20 average score 75.17 epsilon 0.01
# episode  188 score 171.63 average score 77.13 epsilon 0.01
# episode  189 score 249.49 average score 80.70 epsilon 0.01
# episode  190 score 201.48 average score 84.18 epsilon 0.01
# episode  191 score 206.02 average score 86.79 epsilon 0.01
# episode  192 score 277.25 average score 89.69 epsilon 0.01
# episode  193 score -0.23 average score 90.16 epsilon 0.01
# episode  194 score 221.06 average score 92.93 epsilon 0.01
# episode  195 score 272.87 average score 96.21 epsilon 0.01
# episode  196 score 209.35 average score 98.65 epsilon 0.01
# episode  197 score 6.08 average score 99.37 epsilon 0.01
# episode  198 score 237.57 average score 102.17 epsilon 0.01
# episode  199 score 266.01 average score 104.64 epsilon 0.01
# episode  200 score 12.70 average score 106.03 epsilon 0.01
# episode  201 score 241.61 average score 108.50 epsilon 0.01
# episode  202 score 239.68 average score 111.25 epsilon 0.01
# episode  203 score 198.35 average score 113.83 epsilon 0.01
# episode  204 score 0.41 average score 114.31 epsilon 0.01
# episode  205 score -163.60 average score 112.83 epsilon 0.01
# episode  206 score 218.56 average score 115.18 epsilon 0.01
# episode  207 score -41.59 average score 115.29 epsilon 0.01
# episode  208 score 289.02 average score 116.54 epsilon 0.01
# episode  209 score 270.74 average score 119.40 epsilon 0.01
# episode  210 score 224.09 average score 121.73 epsilon 0.01
# episode  211 score 13.23 average score 120.51 epsilon 0.01
# episode  212 score 270.84 average score 123.70 epsilon 0.01
# episode  213 score 24.95 average score 124.24 epsilon 0.01
# episode  214 score 12.82 average score 122.92 epsilon 0.01
# episode  215 score 21.64 average score 123.35 epsilon 0.01
# episode  216 score 42.52 average score 123.68 epsilon 0.01
# episode  217 score -314.06 average score 120.33 epsilon 0.01
# episode  218 score 218.48 average score 122.64 epsilon 0.01
# episode  219 score 22.32 average score 121.11 epsilon 0.01
# episode  220 score -5.48 average score 121.51 epsilon 0.01
# episode  221 score 275.11 average score 124.70 epsilon 0.01
# episode  222 score 230.25 average score 127.31 epsilon 0.01
# episode  223 score 0.26 average score 127.02 epsilon 0.01
# episode  224 score 109.28 average score 128.33 epsilon 0.01
# episode  225 score 190.61 average score 128.76 epsilon 0.01
# episode  226 score -35.26 average score 126.53 epsilon 0.01
# episode  227 score 243.43 average score 129.07 epsilon 0.01
# episode  228 score 206.34 average score 131.26 epsilon 0.01
# episode  229 score -25.26 average score 129.01 epsilon 0.01
# episode  230 score -90.06 average score 126.16 epsilon 0.01
# episode  231 score 244.56 average score 126.56 epsilon 0.01
# episode  232 score -40.28 average score 126.58 epsilon 0.01
# episode  233 score 6.81 average score 124.87 epsilon 0.01
# episode  234 score 268.25 average score 125.12 epsilon 0.01
# episode  235 score 233.38 average score 125.55 epsilon 0.01
# episode  236 score 238.13 average score 128.17 epsilon 0.01
# episode  237 score -275.38 average score 124.31 epsilon 0.01
# episode  238 score 230.26 average score 124.81 epsilon 0.01
# episode  239 score -51.01 average score 124.18 epsilon 0.01
# episode  240 score -20.55 average score 124.78 epsilon 0.01
# episode  241 score 223.41 average score 126.02 epsilon 0.01
# episode  242 score 170.42 average score 125.43 epsilon 0.01
# episode  243 score 38.62 average score 123.50 epsilon 0.01
# episode  244 score 245.23 average score 123.60 epsilon 0.01
# episode  245 score 10.37 average score 121.83 epsilon 0.01
# episode  246 score 4.01 average score 121.51 epsilon 0.01
# episode  247 score 192.35 average score 121.19 epsilon 0.01
# episode  248 score -224.44 average score 119.61 epsilon 0.01
# episode  249 score -10.56 average score 120.15 epsilon 0.01
# episode  250 score 25.68 average score 118.32 epsilon 0.01
# episode  251 score 222.01 average score 118.60 epsilon 0.01
# episode  252 score 269.74 average score 121.29 epsilon 0.01
# episode  253 score 284.50 average score 123.06 epsilon 0.01
# episode  254 score 231.90 average score 124.46 epsilon 0.01
# episode  255 score 234.08 average score 126.86 epsilon 0.01
# episode  256 score 257.13 average score 130.06 epsilon 0.01
# episode  257 score 256.12 average score 133.30 epsilon 0.01
# episode  258 score 264.69 average score 136.91 epsilon 0.01
# episode  259 score 221.05 average score 138.70 epsilon 0.01
# episode  260 score 264.21 average score 141.41 epsilon 0.01
# episode  261 score 238.46 average score 141.20 epsilon 0.01
# episode  262 score 257.97 average score 144.27 epsilon 0.01
# episode  263 score 208.44 average score 143.81 epsilon 0.01
# episode  264 score 267.01 average score 144.36 epsilon 0.01
# episode  265 score 119.45 average score 143.27 epsilon 0.01
# episode  266 score 27.47 average score 141.60 epsilon 0.01
# episode  267 score 239.68 average score 142.72 epsilon 0.01
# episode  268 score 246.63 average score 144.97 epsilon 0.01
# episode  269 score 232.50 average score 144.87 epsilon 0.01
# episode  270 score 186.49 average score 144.67 epsilon 0.01
# episode  271 score -16.17 average score 142.67 epsilon 0.01
# episode  272 score 240.83 average score 146.17 epsilon 0.01
# episode  273 score 238.27 average score 146.36 epsilon 0.01
# episode  274 score 267.46 average score 149.66 epsilon 0.01
# episode  275 score 257.52 average score 149.17 epsilon 0.01
# episode  276 score 248.50 average score 149.55 epsilon 0.01
# episode  277 score 236.45 average score 149.96 epsilon 0.01
# episode  278 score 255.34 average score 149.92 epsilon 0.01
# episode  279 score 236.95 average score 150.26 epsilon 0.01
# episode  280 score 220.68 average score 150.27 epsilon 0.01
# episode  281 score -251.71 average score 145.60 epsilon 0.01
# episode  282 score -121.40 average score 141.94 epsilon 0.01
# episode  283 score -119.25 average score 138.83 epsilon 0.01
# episode  284 score -113.98 average score 135.59 epsilon 0.01
# episode  285 score 226.05 average score 135.13 epsilon 0.01
# episode  286 score -143.35 average score 131.71 epsilon 0.01
# episode  287 score 46.65 average score 129.68 epsilon 0.01
# episode  288 score 73.97 average score 128.70 epsilon 0.01
# episode  289 score 224.81 average score 128.46 epsilon 0.01
# episode  290 score 234.64 average score 128.79 epsilon 0.01
# episode  291 score 281.60 average score 129.55 epsilon 0.01
# episode  292 score 246.84 average score 129.24 epsilon 0.01
# episode  293 score 201.94 average score 131.26 epsilon 0.01
# episode  294 score 241.31 average score 131.47 epsilon 0.01
# episode  295 score -35.55 average score 128.38 epsilon 0.01
# episode  296 score 280.43 average score 129.09 epsilon 0.01
# episode  297 score 256.60 average score 131.60 epsilon 0.01
# episode  298 score 254.46 average score 131.77 epsilon 0.01
# episode  299 score -34.82 average score 128.76 epsilon 0.01

# %%
pd.DataFrame(information).to_csv("DQN_LL_info.csv", header = True, index = False)
